# %%
from fastai import *
from fastai.vision import *

# %%
folders = ["Andromeda", "Black_Eye", "Bodes", "Cartwheel", "Cigar", "Comet", "Pinwheel", "Sombrero", "Sunflower", "Tadpole", "Whirlpool"]

# %%
path = Path('data/galaxies')
for f in folders:
    dest = path/f
    dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'black'
file = 'urls_black.txt'

# %% [markdown]
# ## Downloading all the images from the csv files curated.
#
# ## After downloading, I hand pruned some of the bad images
#
# The final datasets can be found here:

# %%
for f in folders:
    dest = path/f
    download_images(f"galaxies/{f}.csv", dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 02:02<00:00]
#     </div>
# Error https://images.unsplash.com/photo-1515966306809-37aaff37a72f?ixlib=rb-0.3.5&ixid=eyJhcHBfaWQiOjEyMDd9&s=d4f93cb4c6a31b4af729ccecf6779c59&w=1000&q=80 'content-length'
# Error https://cosmos-images1.imgix.net/file/spina/photo/15878/180727-andromeda-full.jpg?ixlib=rails-2.1.4&auto=format&ch=Width%2CDPR&fit=max&w=835 'content-length'
# Error https://d.ibtimes.co.uk/en/full/1417434/pillars-creation.jpg?w=1180&e=1116306653b053a9b49995c5c13d3360 'content-length'
# Error https://www.universetoday.com/wp-content/uploads/2009/09/Andromeda-Galaxy.jpg 'content-length'
# Error https://www.syfy.com/sites/syfy/files/wire/legacy/hubble_ngc7640.jpg 'content-length'
# Error https://astronomer-wpengine.netdna-ssl.com/wp-content/uploads/2014/12/The-Andromeda-Galaxy-M31-M110-bottom-Terry-Hancock1-300x201.jpg 'content-length'
# ...

# %%
for c in folders:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# Andromeda
#     <div>
#       <progress value='134' max='134', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [134/134 00:12<00:00]
#     </div>
# cannot identify image file '/Users/basepython/Desktop/galaxy-classification/data/galaxies/Andromeda/.DS_Store'
# Black_Eye
#     <div>
#       <progress value='117' max='117', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [117/117 00:02<00:00]
#     </div>
# cannot identify image file '/Users/basepython/Desktop/galaxy-classification/data/galaxies/Black_Eye/.DS_Store'
# Bodes
#     <div>
#       <progress value='134' max='134', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [134/134 00:06<00:00]
#     </div>
# cannot identify image file '/Users/basepython/Desktop/galaxy-classification/data/galaxies/Bodes/.DS_Store'
# ...

# %% [markdown]
# ## View some of the data

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=4)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c
# Out:
# (['Andromeda',
#   'Black_Eye',
#   'Bodes',
#   'Cartwheel',
#   'Cigar',
#   'Comet',
#   'Pinwheel',
#   'Sombrero',
#   'Sunflower',
#   'Tadpole',
#   'Whirlpool'],
#  11)

# %% [markdown]
# ## Training the model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /Users/basepython/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:17<00:00, 4896962.77it/s]
